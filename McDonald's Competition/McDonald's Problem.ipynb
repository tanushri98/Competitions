# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
sns.set(color_codes=True)

# %%
mcd = pd.read_csv('Mcdonald.csv')
breakfast = mcd[mcd['Category'] == 'Breakfast']
cnt = mcd[mcd['Category'] == 'Coffee & Tea']
nonveg1 = mcd[(mcd['Category'] == 'Chicken & Fish')]
nonveg2 = mcd[mcd['Category'] == 'Beef & Pork']
nonveg = pd.concat([nonveg1,nonveg2])
bev1 = mcd[(mcd['Category'] == 'Smoothies & Shakes')]
bev2 = mcd[mcd['Category'] == 'Beverages']
bev = pd.concat([bev1,bev2])
salad = mcd[mcd['Category'] == 'Salads']
desserts = mcd[mcd['Category'] == 'Desserts']
#fig, ax = plt.subplots(figsize=(10,10))
#cnt.sort_values(by=['Calories'], ascending=False).head(19)

# %%
'Category'
'Item'
'Serving Size'
'Calories'
'Calories from Fat'
'Total Fat'
'Total Fat (% Daily Value)'
'Saturated Fat'
'Saturated Fat (% Daily Value)'
'Trans Fat'
'Cholesterol'
'Cholesterol (% Daily Value)'
'Sodium'
'Sodium (% Daily Value)'
'Carbohydrates'
'Carbohydrates (% Daily Value)'
'Dietary Fiber'
'Dietary Fiber (% Daily Value)'
'Sugars'
'Protein'
'Vitamin A (% Daily Value)'
'Vitamin C (% Daily Value)'
'Calcium (% Daily Value)'
'Iron (% Daily Value)'

deep, muted, bright, pastel, dark, colorblind
# Out:
# 'Iron (% Daily Value)'

# %%
df = mcd[mcd['Category'] == 'Protein']
df1 = mcd.sort_values(by=['Protein'],ascending=(True))[['Category','Item','Protein']]
#df1
#df1.groupby('Category')['Trans Fat'].count()

# %%
# fig, ax = plt.subplots(figsize=(10,10))
# sns.pointplot(df1['Sodium (% Daily Value)'],df1['Category'], join = False, palette="colorblind")
# sns.pointplot(df1['Saturated Fat (% Daily Value)'],df1['Item'], hue = df1['Category'], join = False, palette="colorblind")

# %%
# fig, ax = plt.subplots(figsize=(8,8))
# sns.swarmplot(df1['Sodium (% Daily Value)'],df1['Category'],palette="muted")
# sns.stripplot(df1['Cholesterol (% Daily Value)'],df1['Category'], jitter=True)

# %%
fig, ax = plt.subplots(figsize=(13,5))
sns.countplot(df1['Category'])

# %%
mcd.sort_values(by=['Calcium (% Daily Value)'], ascending=False).head(10)[['Category','Item','Calcium (% Daily Value)']]
# Out:
#                Category                                               Item  \
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 246  Smoothies & Shakes                           Strawberry Shake (Large)
# 195        Coffee & Tea             Hot Chocolate with Nonfat Milk (Large)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 243  Smoothies & Shakes                              Vanilla Shake (Large)
# 192        Coffee & Tea                              Hot Chocolate (Large)
# 251  Smoothies & Shakes                             Shamrock Shake (Large)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 177        Coffee & Tea  Nonfat Latte with Sugar Free French Vanilla Sy...
# 174        Coffee & Tea                Nonfat French Vanilla Latte (Large)
#
#      Calcium (% Daily Value)
# 253                       70
# 246                       70
# 195                       60
# ...

# %%
breakfast[(breakfast['Calories'] <= 400) & (breakfast['Calories'] > 150)][['Item','Calories','Protein','Dietary Fiber (% Daily Value)','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)','Total Fat (% Daily Value)']]
# Out:
#                                               Item  Calories  Protein  \
# 0                                     Egg McMuffin       300       17
# 1                                Egg White Delight       250       18
# 2                                 Sausage McMuffin       370       14
# 4                 Sausage McMuffin with Egg Whites       400       21
# 20  Bacon, Egg & Cheese McGriddles with Egg Whites       400       20
# 35                                        Hotcakes       350        8
# 37                                 Sausage Burrito       300       12
# 40                           Fruit & Maple Oatmeal       290        5
# 41       Fruit & Maple Oatmeal without Brown Sugar       260        5
#
#     Dietary Fiber (% Daily Value)  Vitamin A (% Daily Value)  \
# 0                              17                         10
# 1                              17                          6
# 2                              17                          8
# ...
